# %% [markdown]
# <a href="https://colab.research.google.com/github/ravitejabankupalli/python-daily-notebooks/blob/main/Day_1_Python_For_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this note book we are going to learn Python for AIML.
# The Topics for today are as follows:
# 1. variables
# 2. data types
# 3. lists, tuples, dicts (Very basics)

# %%
x=5
y="Ravi"
print(x)
print(y)
# Out:
# 5
# Ravi

# %%
print(x)
x='Ravi'
print(x)
#The memory value of X is replaced by the new assigned value
# Out:
# 5
# Ravi

# %%
x=str(3)
y=int(3)
z=float(3)
a=complex(3)
print(x)
print(y)
print(z)
print(a)
# Out:
# 3
# 3
# 3.0
# (3+0j)

# %%
x=y=z="Apple"
print(x)
print(y)
print(z)
print(x,y,z)
# Out:
# Apple
# Apple
# Apple
# Apple Apple Apple

# %%
x,y,z="Apple","Ball","Cat"
print(x)
print(y)
print(z)
print(x,y,z)
# Out:
# Apple
# Ball
# Cat
# Apple Ball Cat

# %%
fruits=["a","b","c"]
x,y,z=fruits
print(x)
print(y)
print(z)
# Out:
# a
# b
# c

# %%
## We use type() to get the type of a variable.
type(x)
# Out:
# str

# %%
x=3
type(x)
# Out:
# int

# %%
x=1+3j
type(x)
# Out:
# complex

# %%
x=1.2
type(x)
# Out:
# float

# %%
x="Hello World"
print(x)
# Out:
# Hello World

# %%
print(x[1:2])
# Out:
# e

# %%
print(x[1:3])
# Out:
# el

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.split(" ")
# Out:
# ['Hello', 'World']

# %%
x
# Out:
# 'Hello World'

# %%
x[:3]=3
#We cannot modify a str in python
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4157218361.py in <cell line: 0>()
# ----> 1 x[:3]=3
#       2 #We cannot modify a str in python
#
# TypeError: 'str' object does not support item assignment

# %%
x=20
y=30
print(x>y)
# Out:
# False

# %%
print(y>x)
# Out:
# True

# %%
#List
a=["a","b","c"]
print(a)
# Out:
# ['a', 'b', 'c']

# %%
print(a[1:2])
#[Staring point which is included : Ending point which is not included]
# Out:
# ['b']

# %%
print(a[1:3])
# Out:
# ['b', 'c']

# %%
print(a[1:4])
# Out:
# ['b', 'c']

# %%
a[0]="Apple" #Lists are mutable
print(a)
#Assigning/modifying the list
# Out:
# ['Apple', 'b', 'c']

# %%
##we can change multiple values at the same time
a[0:2]="Apple"
print(a)
# Out:
# ['A', 'p', 'p', 'l', 'e', 'c']

# %%
a
# Out:
# ['A', 'p', 'p', 'l', 'e', 'c']

# %%
a=["a","b","c"]
a
# Out:
# ['a', 'b', 'c']

# %%
a[0:2]=["Apple","Ball"]
a
# Out:
# ['Apple', 'Ball']

# %%
a.remove("Apple")
print(a)
##Remove function will only if you give an item in the list which is there. if the item is not there in the list it will through an error
# Out:
# ['Ball']

# %%
a
# Out:
# ['Ball']

# %%
a.pop()
# Out:
# 'Ball'

# %%
a
# Out:
# []

# %%
a=["Apple","Ball","Cat"]
a
# Out:
# ['Apple', 'Ball', 'Cat']

# %%
a.pop()
#Pop removes the last item in the list
# Out:
# 'Cat'

# %%
#Tupples
#list is in between []
#Tupple is in between ()

a=("Apple","Ball","Cat","Dog")
print(a)
# Out:
# ('Apple', 'Ball', 'Cat', 'Dog')

# %%
a[1]
# Out:
# 'Ball'

# %%
a[1:2]
# Out:
# ('Ball',)

# %%
#Tupples are immutable means we cannot change the values once created
a[0]="Sample"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1683805014.py in <cell line: 0>()
#       1 #Tupples are immutable
# ----> 2 a[0]="Sample"
#
# TypeError: 'tuple' object does not support item assignment

# %%
a.pop
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4151813069.py in <cell line: 0>()
# ----> 1 a.pop
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
#Dictoinaries
#Dictionaries is in between {}
dict={"name":"Ravi", "age":"28", "role":"AIML Engineer", "company":"Amazon"}
dict
# Out:
# {'name': 'Ravi', 'age': '28', 'role': 'AIML Engineer', 'company': 'Amazon'}

# %%
dict["name"]
# Out:
# 'Ravi'

# %%
dict["Company"]="Meta"
print(dict)
# Out:
# {'name': 'Ravi', 'age': '28', 'role': 'AIML Engineer', 'company': 'Amazon', 'Company': 'Meta'}

# %%
dict.remove("Company")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-916545728.py in <cell line: 0>()
# ----> 1 dict.remove("Company")
#
# AttributeError: 'dict' object has no attribute 'remove'

# %%
del dict["Company"]

# %%
dict
# Out:
# {'name': 'Ravi', 'age': '28', 'role': 'AIML Engineer', 'company': 'Amazon'}

# %%
dict["company"]="Alphabet"

# %%
dict
# Out:
# {'name': 'Ravi', 'age': '28', 'role': 'AIML Engineer', 'company': 'Alphabet'}

# %%
##Sets
#sets are in between {} but they are not in key value pairs#
#a Set will automatically sory the values.
a={4,1,2,7,3,6,9,8}
a
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9}

# %%
#It can sort both numbers and strings.
a={4,1,2,7,3,6,9,8,"a","d","g","h"}
a
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9, 'a', 'd', 'g', 'h'}

# %%
a[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-240059899.py in <cell line: 0>()
# ----> 1 a[1]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Finally
# 1. A List is in between [], it is mutable
# 2. A Tuple is in between (), it is immutable
# 3. A Dictionary is in between {}, it is in key values pairs like {"name":"Ravi", "Age":29}, we can access the dict using the keys, keys should be unique
# 4. A Set is in between {}, it automatically sorts the elements in it,it is immutable, and we cannot access the elements in the set like list and tuple. we can only iterate through them.
